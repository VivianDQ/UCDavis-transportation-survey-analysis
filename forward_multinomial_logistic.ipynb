# %%
import pandas as pd
import numpy as np
import time
import collections

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
import statsmodels.discrete.discrete_model as sm

# %%
class Classify:
    def __init__(self, col):
        # self.data = data
        self.data = None
        self.col = col
        
    def process_data(self, data):
        col = self.col
        xname = [# 'primary_role',
                'op_travel_wasted',
                'op_like_biking',
                'op_eco_concern',
                'op_like_driving',
                'op_need_car',
                'op_schedule_transit',
                'op_feel_safe',
                'op_like_transit',
                'op_need_own_car',
                'op_limit_driving',
                'op_smartphone',
                'op_dress_professional',
                'op_travel_stress']
        data[col].replace(['Personal bike', 'Bike share (e.g. JUMP)'], 'bike', inplace = True)
        data[col].replace(['Bus and/or shuttle', 'Train and/or light rail'], 'bus', inplace = True)
        data[col].replace(['Lyft, Uber, or other ride-hailing service', 'Carpool and/or vanpool with others', 'Drive alone in a car (or other vehicle)', 'Get dropped off by a friend of family'], 'drive', inplace = True)
        data[col].replace(['Walk (or wheelchair)', 'Skate, skateboard, or scooter', 'Other:'], 'other', inplace = True)
        if col == 'lastmile_bus':
            data[col].replace(['drive'], 'other', inplace = True)
        if col == 'lastmile_train':
            data[col].replace(['Get dropped off by a friend or family'], 'drive', inplace = True)
            # data[col].replace(['drive'], 'drive&bus', inplace = True)
            # data[col].replace(['bus'], 'drive&bus', inplace = True)
        if col == 'firstmile_train':
            data[col].replace(['bus'], 'other', inplace = True)
        data.replace(['Strongly agree'], 5, inplace = True)
        data.replace(['Somewhat agree'], 4, inplace = True)
        data.replace(['Neither agree nor disagree'], 3, inplace = True)
        data.replace(['Somewhat disagree'], 2, inplace = True)
        data.replace(['Strongly disagree'], 1, inplace = True)
        
        data['primary_role'].replace(['Undergraduate student (including Post-baccalaureate)'], 'undergra', inplace = True)
        data['primary_role'].replace(['Graduate student'], 'gra', inplace = True)
        data['primary_role'].replace(['Faculty'], 'fac', inplace = True)
        data['primary_role'].replace(["I'm no longer affiliated with UC Davis", 'Other:'], 'other', inplace = True)
        data['primary_role'].replace(['Visiting scholar', 'Staff', 'Post doc'], 'staff', inplace = True)
        
        data[col].replace(['bike'], 1, inplace = True)
        data[col].replace(['bus'], 2, inplace = True)
        data[col].replace(['drive'], 3, inplace = True)
        data[col].replace(['other'], 4, inplace = True)
        
        data = data.dropna(subset=[col] + xname + ['primary_role'])
        
        df1 = data[xname+[col]]
        self.data = pd.concat([df1, pd.get_dummies(data['primary_role'])], axis=1)
        # self.data = pd.get_dummies(data)
        return self.data
    
    def forward_selected(self):
        """Linear model designed by forward selection.

        Parameters:
        -----------
        data : pandas DataFrame with all possible predictors and response

        response: string, name of response column in data

        Returns:
        --------
        model: an "optimal" fitted statsmodels linear model
               with an intercept
               selected by forward selection
               evaluated by adjusted R-squared
        """
        response = self.col
        data = self.data
        remaining = set(data.columns)
        print(remaining)
        remaining.remove(response)
        selected = []
        current_score, best_new_score = float('Inf'), float('Inf')
        # print(remaining)
        while remaining and current_score == best_new_score:
            scores_with_candidates = []
            for candidate in remaining:
                l = sm.MNLogit(data[response].astype(int), data[selected+[candidate]].astype(int)).fit_regularized(penalty = 'l2')
                score = l.aic
                scores_with_candidates.append((score, candidate))
            scores_with_candidates.sort(reverse = True)
            best_new_score, best_candidate = scores_with_candidates.pop()
            # print(current_score, best_new_score)
            if current_score > best_new_score:
                remaining.remove(best_candidate)
                selected.append(best_candidate)
                current_score = best_new_score
        model = sm.MNLogit(data[response].astype(int), data[selected].astype(int)).fit_regularized(penalty = 'l2')
        return model

# %%
# Load the data
# data_dic = pd.read_csv("data/cts1819_data_dictionary.csv")
data = pd.read_csv("data/CTS_noID_1819.csv")

# %%
colname = 'firstmile_bus'
task = Classify(colname)
d = task.process_data(data)
print(d.shape)
firstmile_bus = task.forward_selected()
# Out:
# (898, 19)
# {'op_need_car', 'op_limit_driving', 'gra', 'other', 'op_like_biking', 'op_schedule_transit', 'op_like_driving', 'op_need_own_car', 'op_travel_stress', 'firstmile_bus', 'staff', 'undergra', 'op_like_transit', 'op_feel_safe', 'op_dress_professional', 'op_travel_wasted', 'fac', 'op_smartphone', 'op_eco_concern'}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5672033301908667
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5617964909730151
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2857602718620051
#             Iterations: 32
#             Function evaluations: 32
#             Gradient evaluations: 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.383206845922618
#             Iterations: 28
#             Function evaluations: 29
#             Gradient evaluations: 28
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6236437888469132
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6733625537724712
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5610489937779964
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6578432446692981
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6148134572112365
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.381137551741124
#             Iterations: 29
#             Function evaluations: 29
#             Gradient evaluations: 29
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6098411290515795
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5527551284450061
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5731419169364608
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6324513523648347
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5728545477188167
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3795380222783316
#             Iterations: 27
#             Function evaluations: 27
#             Gradient evaluations: 27
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5216705638100434
#             Iterations: 12
#             Function evaluations: 15
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5955389037073086
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5132426705663219
#             Iterations: 29
#             Function evaluations: 32
#             Gradient evaluations: 29
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5139137537631379
#             Iterations: 30
#             Function evaluations: 33
#             Gradient evaluations: 30
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5190633389319328
#             Iterations: 38
#             Function evaluations: 40
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5213634553807636
#             Iterations: 41
#             Function evaluations: 44
#             Gradient evaluations: 41
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5141611900488867
#             Iterations: 27
#             Function evaluations: 30
#             Gradient evaluations: 27
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5205803373526544
#             Iterations: 25
#             Function evaluations: 27
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5109876462498202
#             Iterations: 25
#             Function evaluations: 28
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5198207708623317
#             Iterations: 24
#             Function evaluations: 26
#             Gradient evaluations: 24
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5172776992941757
#             Iterations: 25
#             Function evaluations: 27
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.517020876767452
#             Iterations: 42
#             Function evaluations: 45
#             Gradient evaluations: 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5061209092173882
#             Iterations: 33
#             Function evaluations: 36
#             Gradient evaluations: 33
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5093529793414167
#             Iterations: 28
#             Function evaluations: 31
#             Gradient evaluations: 28
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5117161976409688
#             Iterations: 29
#             Function evaluations: 32
#             Gradient evaluations: 29
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.520943991462494
#             Iterations: 25
#             Function evaluations: 27
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5151415899949328
#             Iterations: 25
#             Function evaluations: 28
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5176434601451849
#             Iterations: 39
#             Function evaluations: 41
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5173164494076927
#             Iterations: 28
#             Function evaluations: 31
#             Gradient evaluations: 28
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5021378583674939
#             Iterations: 49
#             Function evaluations: 52
#             Gradient evaluations: 49
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5004415391864107
#             Iterations: 54
#             Function evaluations: 57
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4936991201585391
#             Iterations: 61
#             Function evaluations: 64
#             Gradient evaluations: 61
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5054563870507809
#             Iterations: 63
#             Function evaluations: 65
#             Gradient evaluations: 63
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4974571942128458
#             Iterations: 50
#             Function evaluations: 53
#             Gradient evaluations: 50
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.504850617627999
#             Iterations: 54
#             Function evaluations: 56
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5018898796059584
#             Iterations: 48
#             Function evaluations: 51
#             Gradient evaluations: 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5055984886435726
#             Iterations: 54
#             Function evaluations: 57
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5047456977096609
#             Iterations: 52
#             Function evaluations: 54
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5047469490941484
#             Iterations: 66
#             Function evaluations: 68
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4967407553191134
#             Iterations: 52
#             Function evaluations: 55
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4972267906702488
#             Iterations: 55
#             Function evaluations: 58
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5056652836967994
#             Iterations: 47
#             Function evaluations: 50
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5039791034500086
#             Iterations: 48
#             Function evaluations: 51
#             Gradient evaluations: 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5052305190602415
#             Iterations: 60
#             Function evaluations: 62
#             Gradient evaluations: 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5030160587861201
#             Iterations: 53
#             Function evaluations: 56
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4923026079040805
#             Iterations: 74
#             Function evaluations: 78
#             Gradient evaluations: 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4906991285530384
#             Iterations: 75
#             Function evaluations: 78
#             Gradient evaluations: 75
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49238630770206165
#             Iterations: 89
#             Function evaluations: 92
#             Gradient evaluations: 89
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4843677185098369
#             Iterations: 63
#             Function evaluations: 67
#             Gradient evaluations: 63
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49116863299573077
#             Iterations: 72
#             Function evaluations: 74
#             Gradient evaluations: 72
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4918010351755644
#             Iterations: 73
#             Function evaluations: 76
#             Gradient evaluations: 73
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4930460846028813
#             Iterations: 74
#             Function evaluations: 76
#             Gradient evaluations: 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49365087906379956
#             Iterations: 74
#             Function evaluations: 76
#             Gradient evaluations: 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49339787443695066
#             Iterations: 93
#             Function evaluations: 95
#             Gradient evaluations: 93
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48839200269500316
#             Iterations: 73
#             Function evaluations: 76
#             Gradient evaluations: 73
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48650116228235357
#             Iterations: 73
#             Function evaluations: 76
#             Gradient evaluations: 73
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49300965398438273
#             Iterations: 74
#             Function evaluations: 76
#             Gradient evaluations: 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4932723408373959
#             Iterations: 75
#             Function evaluations: 78
#             Gradient evaluations: 75
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49307409291797316
#             Iterations: 96
#             Function evaluations: 98
#             Gradient evaluations: 96
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.49210431831283064
#             Iterations: 74
#             Function evaluations: 77
#             Gradient evaluations: 74
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4814724495116361
#             Iterations: 86
#             Function evaluations: 88
#             Gradient evaluations: 86
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48137397411378424
#             Iterations: 93
#             Function evaluations: 96
#             Gradient evaluations: 93
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48288505124530184
#             Iterations: 102
#             Function evaluations: 105
#             Gradient evaluations: 102
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48273200427326185
#             Iterations: 85
#             Function evaluations: 88
#             Gradient evaluations: 85
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4810214644695512
#             Iterations: 87
#             Function evaluations: 90
#             Gradient evaluations: 87
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4839693820149065
#             Iterations: 76
#             Function evaluations: 79
#             Gradient evaluations: 76
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48377439969163655
#             Iterations: 87
#             Function evaluations: 90
#             Gradient evaluations: 87
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4838906722227489
#             Iterations: 111
#             Function evaluations: 114
#             Gradient evaluations: 111
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4722741240385635
#             Iterations: 89
#             Function evaluations: 92
#             Gradient evaluations: 89
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48078965560758546
#             Iterations: 89
#             Function evaluations: 92
#             Gradient evaluations: 89
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4834527141424103
#             Iterations: 87
#             Function evaluations: 90
#             Gradient evaluations: 87
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48237849060888655
#             Iterations: 88
#             Function evaluations: 91
#             Gradient evaluations: 88
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4822098741180909
#             Iterations: 101
#             Function evaluations: 104
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48272158565846224
#             Iterations: 88
#             Function evaluations: 91
#             Gradient evaluations: 88
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4697227909349463
#             Iterations: 100
#             Function evaluations: 103
#             Gradient evaluations: 100
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47103730410390504
#             Iterations: 101
#             Function evaluations: 104
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47091361022993916
#             Iterations: 119
#             Function evaluations: 123
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4710912500347194
#             Iterations: 100
#             Function evaluations: 103
#             Gradient evaluations: 100
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4694057762405865
#             Iterations: 100
#             Function evaluations: 104
#             Gradient evaluations: 100
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4718166797516325
#             Iterations: 90
#             Function evaluations: 93
#             Gradient evaluations: 90
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4719375886152662
#             Iterations: 100
#             Function evaluations: 103
#             Gradient evaluations: 100
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.471970438389836
#             Iterations: 119
#             Function evaluations: 122
#             Gradient evaluations: 119
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4686190152678438
#             Iterations: 108
#             Function evaluations: 111
#             Gradient evaluations: 108
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4702729345839351
#             Iterations: 99
#             Function evaluations: 102
#             Gradient evaluations: 99
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4706213726299524
#             Iterations: 101
#             Function evaluations: 105
#             Gradient evaluations: 101
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47173226267490537
#             Iterations: 123
#             Function evaluations: 127
#             Gradient evaluations: 123
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4720926684014188
#             Iterations: 102
#             Function evaluations: 106
#             Gradient evaluations: 102
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4661356864727083
#             Iterations: 116
#             Function evaluations: 120
#             Gradient evaluations: 116
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46740134972482084
#             Iterations: 118
#             Function evaluations: 122
#             Gradient evaluations: 118
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46728183944660284
#             Iterations: 132
#             Function evaluations: 135
#             Gradient evaluations: 132
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46744541229768877
#             Iterations: 114
#             Function evaluations: 117
#             Gradient evaluations: 114
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46609024497128637
#             Iterations: 117
#             Function evaluations: 120
#             Gradient evaluations: 117
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4681648211900211
#             Iterations: 121
#             Function evaluations: 124
#             Gradient evaluations: 121
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4683377293483985
#             Iterations: 104
#             Function evaluations: 108
#             Gradient evaluations: 104
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4684133478899663
#             Iterations: 123
#             Function evaluations: 127
#             Gradient evaluations: 123
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46659814831364993
#             Iterations: 116
#             Function evaluations: 119
#             Gradient evaluations: 116
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46695461313723835
#             Iterations: 116
#             Function evaluations: 121
#             Gradient evaluations: 116
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.46800271189939213
#             Iterations: 144
#             Function evaluations: 148
#             Gradient evaluations: 144
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4683903407376189
#             Iterations: 117
#             Function evaluations: 120
#             Gradient evaluations: 117
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4686190152678438
#             Iterations: 108
#             Function evaluations: 111
#             Gradient evaluations: 108

# %%
colname = 'firstmile_train'
task = Classify(colname)
d = task.process_data(data)
print(d.shape)
firstmile_train = task.forward_selected()
# Out:
# (74, 18)
# {'op_need_car', 'op_limit_driving', 'gra', 'staff', 'op_like_biking', 'op_schedule_transit', 'op_like_driving', 'op_need_own_car', 'op_travel_stress', 'undergra', 'op_like_transit', 'op_feel_safe', 'op_dress_professional', 'op_travel_wasted', 'fac', 'op_smartphone', 'firstmile_train', 'op_eco_concern'}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0550238014880513
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0666031210197153
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0501097617969486
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0460676066230268
#             Iterations: 37
#             Function evaluations: 38
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0686000520554482
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0688048937544188
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0430885061665116
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0663224042404855
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0636077767292273
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.002588109416632
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.071329594948284
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.069747506208919
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0700448638622237
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0661532607417878
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0977837346249981
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0684422858470073
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0713165834853076
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9938519209557231
#             Iterations: 16
#             Function evaluations: 17
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9847439100044144
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9540855825448328
#             Iterations: 23
#             Function evaluations: 24
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9500434273513689
#             Iterations: 47
#             Function evaluations: 48
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9662581985738433
#             Iterations: 17
#             Function evaluations: 19
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9876160269955513
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9841742948875133
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9816857458667572
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9853864199078302
#             Iterations: 18
#             Function evaluations: 19
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9773615283011002
#             Iterations: 14
#             Function evaluations: 15
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9652954072797142
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9884564212436846
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9992060598683473
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0017595553589684
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9794505562843316
#             Iterations: 16
#             Function evaluations: 17
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9716101604953677
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9451147299810551
#             Iterations: 52
#             Function evaluations: 53
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9317220771217434
#             Iterations: 52
#             Function evaluations: 53
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9015409005365698
#             Iterations: 57
#             Function evaluations: 57
#             Gradient evaluations: 57
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.910426011128709
#             Iterations: 52
#             Function evaluations: 54
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9300106773839666
#             Iterations: 53
#             Function evaluations: 54
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9325705458169627
#             Iterations: 55
#             Function evaluations: 56
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9248122774892491
#             Iterations: 53
#             Function evaluations: 54
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9311660404522384
#             Iterations: 53
#             Function evaluations: 55
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9219624389365944
#             Iterations: 51
#             Function evaluations: 52
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9095798921473882
#             Iterations: 52
#             Function evaluations: 53
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9360137584163095
#             Iterations: 52
#             Function evaluations: 54
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9327177177913268
#             Iterations: 54
#             Function evaluations: 54
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9492148732802766
#             Iterations: 57
#             Function evaluations: 58
#             Gradient evaluations: 57
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9214025380964286
#             Iterations: 52
#             Function evaluations: 53
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9158891100993829
#             Iterations: 52
#             Function evaluations: 53
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8910392896588227
#             Iterations: 64
#             Function evaluations: 66
#             Gradient evaluations: 64
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8999466085871296
#             Iterations: 65
#             Function evaluations: 66
#             Gradient evaluations: 65
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8953903805286035
#             Iterations: 64
#             Function evaluations: 66
#             Gradient evaluations: 64
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9015317865668814
#             Iterations: 65
#             Function evaluations: 65
#             Gradient evaluations: 65
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9003615440684256
#             Iterations: 67
#             Function evaluations: 67
#             Gradient evaluations: 67
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9001279848782686
#             Iterations: 48
#             Function evaluations: 48
#             Gradient evaluations: 48
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9009109203278879
#             Iterations: 65
#             Function evaluations: 66
#             Gradient evaluations: 65
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.900182966047929
#             Iterations: 50
#             Function evaluations: 51
#             Gradient evaluations: 50
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8945209644576833
#             Iterations: 63
#             Function evaluations: 65
#             Gradient evaluations: 63
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9007958876487471
#             Iterations: 64
#             Function evaluations: 65
#             Gradient evaluations: 64
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8895958643691112
#             Iterations: 65
#             Function evaluations: 65
#             Gradient evaluations: 65
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.900712346380596
#             Iterations: 66
#             Function evaluations: 67
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9013149618901363
#             Iterations: 66
#             Function evaluations: 67
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8984526364320878
#             Iterations: 50
#             Function evaluations: 51
#             Gradient evaluations: 50
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9015409005365698
#             Iterations: 57
#             Function evaluations: 57
#             Gradient evaluations: 57

# %%
colname = 'lastmile_bus'
task = Classify(colname)
d = task.process_data(data)
print(d.shape)
lastmile_bus = task.forward_selected()
# Out:
# (898, 19)
# {'op_need_car', 'op_limit_driving', 'gra', 'other', 'op_like_biking', 'op_schedule_transit', 'op_like_driving', 'op_need_own_car', 'op_travel_stress', 'lastmile_bus', 'staff', 'undergra', 'op_like_transit', 'op_feel_safe', 'op_dress_professional', 'op_travel_wasted', 'fac', 'op_smartphone', 'op_eco_concern'}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.41393356941890697
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.40825061470440094
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.012464898661371
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.096165490794393
#             Iterations: 28
#             Function evaluations: 29
#             Gradient evaluations: 28
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.47078243510166223
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4721144163095084
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4083736656191287
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4659018485759751
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.44243435904435113
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0868204543464395
#             Iterations: 38
#             Function evaluations: 39
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.48774660540940945
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4032368089716099
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.4395614378647252
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.45003179660232984
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.41564270847297136
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0814555918433584
#             Iterations: 39
#             Function evaluations: 39
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3868887813918677
#             Iterations: 10
#             Function evaluations: 12
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.42627205587907274
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3796043039914996
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38076379868989335
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38600885856365463
#             Iterations: 28
#             Function evaluations: 30
#             Gradient evaluations: 28
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3866345631402156
#             Iterations: 35
#             Function evaluations: 37
#             Gradient evaluations: 35
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3777152824579718
#             Iterations: 23
#             Function evaluations: 25
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38453566705465925
#             Iterations: 25
#             Function evaluations: 26
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.37708641311608726
#             Iterations: 25
#             Function evaluations: 27
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3833649714095205
#             Iterations: 22
#             Function evaluations: 25
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38144214737275406
#             Iterations: 23
#             Function evaluations: 26
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38649316239195347
#             Iterations: 42
#             Function evaluations: 44
#             Gradient evaluations: 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38231760053950486
#             Iterations: 26
#             Function evaluations: 28
#             Gradient evaluations: 26
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3771484418103616
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38127338210804734
#             Iterations: 25
#             Function evaluations: 27
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38498695675427796
#             Iterations: 19
#             Function evaluations: 21
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3803709335015124
#             Iterations: 20
#             Function evaluations: 22
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.38605294982131294
#             Iterations: 47
#             Function evaluations: 49
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3822728887264896
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3756717658202288
#             Iterations: 32
#             Function evaluations: 35
#             Gradient evaluations: 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3734608059110031
#             Iterations: 31
#             Function evaluations: 34
#             Gradient evaluations: 31
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3762213008949719
#             Iterations: 38
#             Function evaluations: 40
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.37677939277053524
#             Iterations: 51
#             Function evaluations: 54
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3636989330322309
#             Iterations: 33
#             Function evaluations: 36
#             Gradient evaluations: 33
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.37619034723919076
#             Iterations: 35
#             Function evaluations: 38
#             Gradient evaluations: 35
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3756514165958916
#             Iterations: 34
#             Function evaluations: 37
#             Gradient evaluations: 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3748171067933998
#             Iterations: 32
#             Function evaluations: 35
#             Gradient evaluations: 32
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3766942294601016
#             Iterations: 60
#             Function evaluations: 62
#             Gradient evaluations: 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3758699710214801
#             Iterations: 39
#             Function evaluations: 41
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3711785747674381
#             Iterations: 33
#             Function evaluations: 36
#             Gradient evaluations: 33
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36996514984904794
#             Iterations: 34
#             Function evaluations: 37
#             Gradient evaluations: 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.37678575400768416
#             Iterations: 31
#             Function evaluations: 34
#             Gradient evaluations: 31
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.37462864464267914
#             Iterations: 30
#             Function evaluations: 33
#             Gradient evaluations: 30
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3762571487201908
#             Iterations: 58
#             Function evaluations: 61
#             Gradient evaluations: 58
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3750546915596717
#             Iterations: 30
#             Function evaluations: 33
#             Gradient evaluations: 30
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36149231538843857
#             Iterations: 39
#             Function evaluations: 42
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35429625646980145
#             Iterations: 34
#             Function evaluations: 37
#             Gradient evaluations: 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3628913417464379
#             Iterations: 49
#             Function evaluations: 53
#             Gradient evaluations: 49
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3632484182756697
#             Iterations: 61
#             Function evaluations: 65
#             Gradient evaluations: 61
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36331947555239746
#             Iterations: 40
#             Function evaluations: 42
#             Gradient evaluations: 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36277471203857875
#             Iterations: 39
#             Function evaluations: 41
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35958690665607373
#             Iterations: 39
#             Function evaluations: 41
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.363507558507462
#             Iterations: 70
#             Function evaluations: 74
#             Gradient evaluations: 70
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36186572166909475
#             Iterations: 47
#             Function evaluations: 50
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35080351961888145
#             Iterations: 34
#             Function evaluations: 37
#             Gradient evaluations: 34
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36272774619098613
#             Iterations: 42
#             Function evaluations: 46
#             Gradient evaluations: 42
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.36196884140842495
#             Iterations: 40
#             Function evaluations: 42
#             Gradient evaluations: 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3587659237774389
#             Iterations: 33
#             Function evaluations: 36
#             Gradient evaluations: 33
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3628439812334123
#             Iterations: 69
#             Function evaluations: 73
#             Gradient evaluations: 69
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3561215357087488
#             Iterations: 40
#             Function evaluations: 43
#             Gradient evaluations: 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3494435198517889
#             Iterations: 43
#             Function evaluations: 46
#             Gradient evaluations: 43
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34549176150770367
#             Iterations: 51
#             Function evaluations: 54
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.350513902998687
#             Iterations: 58
#             Function evaluations: 61
#             Gradient evaluations: 58
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35026266905605574
#             Iterations: 59
#             Function evaluations: 62
#             Gradient evaluations: 59
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3502649217903699
#             Iterations: 44
#             Function evaluations: 47
#             Gradient evaluations: 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3500670448996839
#             Iterations: 47
#             Function evaluations: 50
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34775960686711077
#             Iterations: 49
#             Function evaluations: 53
#             Gradient evaluations: 49
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35061937725432507
#             Iterations: 78
#             Function evaluations: 82
#             Gradient evaluations: 78
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3491403988524477
#             Iterations: 60
#             Function evaluations: 63
#             Gradient evaluations: 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3499913983267904
#             Iterations: 45
#             Function evaluations: 49
#             Gradient evaluations: 45
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3503269042316776
#             Iterations: 44
#             Function evaluations: 47
#             Gradient evaluations: 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3469770921155833
#             Iterations: 45
#             Function evaluations: 48
#             Gradient evaluations: 45
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.35043351923638044
#             Iterations: 79
#             Function evaluations: 82
#             Gradient evaluations: 79
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3470614177109677
#             Iterations: 44
#             Function evaluations: 47
#             Gradient evaluations: 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34448194644669966
#             Iterations: 54
#             Function evaluations: 59
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34523679085864367
#             Iterations: 68
#             Function evaluations: 71
#             Gradient evaluations: 68
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3449680626179527
#             Iterations: 79
#             Function evaluations: 83
#             Gradient evaluations: 79
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34530440036413906
#             Iterations: 63
#             Function evaluations: 66
#             Gradient evaluations: 63
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3447650744280142
#             Iterations: 55
#             Function evaluations: 59
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34398095176520604
#             Iterations: 52
#             Function evaluations: 56
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34528123757793333
#             Iterations: 89
#             Function evaluations: 92
#             Gradient evaluations: 89
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34387435674490013
#             Iterations: 60
#             Function evaluations: 64
#             Gradient evaluations: 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3443632858086941
#             Iterations: 59
#             Function evaluations: 62
#             Gradient evaluations: 59
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34516566213328537
#             Iterations: 56
#             Function evaluations: 59
#             Gradient evaluations: 56
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3430863372772768
#             Iterations: 55
#             Function evaluations: 58
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3451950590983973
#             Iterations: 88
#             Function evaluations: 91
#             Gradient evaluations: 88
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34405563675358963
#             Iterations: 57
#             Function evaluations: 60
#             Gradient evaluations: 57
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34263472684539525
#             Iterations: 59
#             Function evaluations: 64
#             Gradient evaluations: 59
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34284120406103197
#             Iterations: 72
#             Function evaluations: 75
#             Gradient evaluations: 72
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3426316518273674
#             Iterations: 79
#             Function evaluations: 83
#             Gradient evaluations: 79
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34289661372505853
#             Iterations: 66
#             Function evaluations: 71
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34207382331982034
#             Iterations: 57
#             Function evaluations: 62
#             Gradient evaluations: 57
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3426923012383276
#             Iterations: 59
#             Function evaluations: 65
#             Gradient evaluations: 59
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34288762064518485
#             Iterations: 99
#             Function evaluations: 103
#             Gradient evaluations: 99
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3420371938772282
#             Iterations: 72
#             Function evaluations: 76
#             Gradient evaluations: 72
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34183989519185626
#             Iterations: 60
#             Function evaluations: 64
#             Gradient evaluations: 60
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3427393597905282
#             Iterations: 58
#             Function evaluations: 63
#             Gradient evaluations: 58
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34278517844419887
#             Iterations: 99
#             Function evaluations: 102
#             Gradient evaluations: 99
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.34177709507610793
#             Iterations: 59
#             Function evaluations: 65
#             Gradient evaluations: 59
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.3430863372772768
#             Iterations: 55
#             Function evaluations: 58
#             Gradient evaluations: 55

# %%
colname = 'lastmile_train'
task = Classify(colname)
d = task.process_data(data)
print(d.shape)
lastmile_train = task.forward_selected()
# Out:
# (74, 18)
# {'op_need_car', 'op_limit_driving', 'gra', 'staff', 'op_like_biking', 'op_schedule_transit', 'op_like_driving', 'op_need_own_car', 'op_travel_stress', 'undergra', 'op_like_transit', 'op_feel_safe', 'op_dress_professional', 'op_travel_wasted', 'lastmile_train', 'fac', 'op_smartphone', 'op_eco_concern'}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.232888411331522
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1775322537137303
#             Iterations: 7
#             Function evaluations: 8
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2270135035879837
#             Iterations: 45
#             Function evaluations: 45
#             Gradient evaluations: 45
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.330093238456962
#             Iterations: 36
#             Function evaluations: 37
#             Gradient evaluations: 36
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1647449330978976
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.241580406488901
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2232993245788029
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2677053196204386
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2145530478796693
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.363313213331256
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.137011511991408
#             Iterations: 8
#             Function evaluations: 9
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1595445556361874
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.181523465352086
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2387271207948172
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2295957400540511
#             Iterations: 37
#             Function evaluations: 37
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.216459650846283
#             Iterations: 8
#             Function evaluations: 9
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1628879351538899
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0389527690207945
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.118180166286517
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.077667826537911
#             Iterations: 49
#             Function evaluations: 50
#             Gradient evaluations: 49
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1210701827372909
#             Iterations: 44
#             Function evaluations: 45
#             Gradient evaluations: 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0973250510371078
#             Iterations: 20
#             Function evaluations: 22
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1129190433232423
#             Iterations: 18
#             Function evaluations: 19
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0938933766564947
#             Iterations: 19
#             Function evaluations: 20
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0829913259057877
#             Iterations: 21
#             Function evaluations: 23
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0981839235047446
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0088434973317995
#             Iterations: 26
#             Function evaluations: 28
#             Gradient evaluations: 26
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.129486388667204
#             Iterations: 16
#             Function evaluations: 18
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1055780797786072
#             Iterations: 19
#             Function evaluations: 21
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1131694280946685
#             Iterations: 18
#             Function evaluations: 19
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0869829215667912
#             Iterations: 44
#             Function evaluations: 45
#             Gradient evaluations: 44
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.080408867932875
#             Iterations: 20
#             Function evaluations: 23
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1264392383137747
#             Iterations: 18
#             Function evaluations: 20
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9556920151241762
#             Iterations: 37
#             Function evaluations: 38
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.004251581178077
#             Iterations: 39
#             Function evaluations: 41
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9834643778221982
#             Iterations: 72
#             Function evaluations: 74
#             Gradient evaluations: 72
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0040019323326994
#             Iterations: 66
#             Function evaluations: 67
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9384275910960171
#             Iterations: 40
#             Function evaluations: 42
#             Gradient evaluations: 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0068606303550638
#             Iterations: 38
#             Function evaluations: 39
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9837710907010762
#             Iterations: 39
#             Function evaluations: 40
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9986699909393518
#             Iterations: 39
#             Function evaluations: 40
#             Gradient evaluations: 39
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9949872605505294
#             Iterations: 37
#             Function evaluations: 39
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9540618669596579
#             Iterations: 41
#             Function evaluations: 43
#             Gradient evaluations: 41
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9777069914809884
#             Iterations: 37
#             Function evaluations: 38
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0022682101915101
#             Iterations: 38
#             Function evaluations: 39
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9720677817609211
#             Iterations: 66
#             Function evaluations: 67
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9968254495050449
#             Iterations: 40
#             Function evaluations: 42
#             Gradient evaluations: 40
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0063093922059216
#             Iterations: 38
#             Function evaluations: 40
#             Gradient evaluations: 38
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8515039735437624
#             Iterations: 55
#             Function evaluations: 57
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9305177710441639
#             Iterations: 55
#             Function evaluations: 57
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9240560953479402
#             Iterations: 53
#             Function evaluations: 55
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9332010317523769
#             Iterations: 81
#             Function evaluations: 84
#             Gradient evaluations: 81
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9222025396469546
#             Iterations: 51
#             Function evaluations: 53
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9060594898224213
#             Iterations: 53
#             Function evaluations: 55
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9244555069845917
#             Iterations: 51
#             Function evaluations: 53
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9109491026988839
#             Iterations: 51
#             Function evaluations: 53
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.904314935588442
#             Iterations: 56
#             Function evaluations: 58
#             Gradient evaluations: 56
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.887661176601837
#             Iterations: 52
#             Function evaluations: 54
#             Gradient evaluations: 52
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.916261544621079
#             Iterations: 51
#             Function evaluations: 53
#             Gradient evaluations: 51
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9007780704800186
#             Iterations: 80
#             Function evaluations: 82
#             Gradient evaluations: 80
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9300105056031611
#             Iterations: 55
#             Function evaluations: 57
#             Gradient evaluations: 55
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9255692499815215
#             Iterations: 54
#             Function evaluations: 56
#             Gradient evaluations: 54
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8483159545212202
#             Iterations: 69
#             Function evaluations: 72
#             Gradient evaluations: 69
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8395000534635068
#             Iterations: 99
#             Function evaluations: 101
#             Gradient evaluations: 99
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8464852592750941
#             Iterations: 92
#             Function evaluations: 94
#             Gradient evaluations: 92
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8495934541661757
#             Iterations: 66
#             Function evaluations: 69
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8249323981537944
#             Iterations: 66
#             Function evaluations: 69
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.837794606646173
#             Iterations: 67
#             Function evaluations: 70
#             Gradient evaluations: 67
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8291189479677383
#             Iterations: 68
#             Function evaluations: 71
#             Gradient evaluations: 68
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8225086375493595
#             Iterations: 70
#             Function evaluations: 73
#             Gradient evaluations: 70
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8153684840382004
#             Iterations: 66
#             Function evaluations: 70
#             Gradient evaluations: 66
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8428102747833955
#             Iterations: 67
#             Function evaluations: 69
#             Gradient evaluations: 67
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8228215445426785
#             Iterations: 93
#             Function evaluations: 95
#             Gradient evaluations: 93
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8420614637760276
#             Iterations: 69
#             Function evaluations: 72
#             Gradient evaluations: 69
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.84709175206203
#             Iterations: 63
#             Function evaluations: 67
#             Gradient evaluations: 63
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8515039735437624
#             Iterations: 55
#             Function evaluations: 57
#             Gradient evaluations: 55

# %%
firstmile_bus.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:          firstmile_bus   No. Observations:                  898
# Model:                        MNLogit   Df Residuals:                      880
# Method:                           MLE   Df Model:                           15
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                 0.08031
# Time:                        15:09:58   Log-Likelihood:                -420.82
# converged:                       True   LL-Null:                       -457.57
# Covariance Type:            nonrobust   LLR p-value:                 1.057e-09
# ===================================================================================
# firstmile_bus=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# op_smartphone       0.2032      0.184      1.107      0.268      -0.156       0.563
# undergra            0.9477      0.595      1.594      0.111      -0.218       2.113
# gra                -0.2016      0.793     -0.254      0.799      -1.756       1.353
# op_like_biking     -0.5352      0.204     -2.625      0.009      -0.935      -0.136
# op_like_transit     0.5256      0.177      2.962      0.003       0.178       0.873
# op_feel_safe       -0.4196      0.207     -2.023      0.043      -0.826      -0.013
# -----------------------------------------------------------------------------------
# firstmile_bus=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# op_smartphone       0.3723      0.209      1.786      0.074      -0.036       0.781
# undergra            0.0937      0.618      0.152      0.880      -1.118       1.306
# gra                -1.1324      0.940     -1.205      0.228      -2.974       0.709
# op_like_biking     -0.5994      0.233     -2.577      0.010      -1.055      -0.144
# op_like_transit     0.1144      0.198      0.577      0.564      -0.275       0.503
# op_feel_safe       -0.0247      0.240     -0.103      0.918      -0.495       0.445
# -----------------------------------------------------------------------------------
# firstmile_bus=4       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# op_smartphone       0.4611      0.132      3.489      0.000       0.202       0.720
# undergra            2.1607      0.402      5.372      0.000       1.372       2.949
# gra                 1.1558      0.485      2.381      0.017       0.204       2.107
# op_like_biking     -0.6359      0.157     -4.049      0.000      -0.944      -0.328
# op_like_transit     0.5045      0.124      4.070      0.000       0.262       0.748
# op_feel_safe       -0.0312      0.152     -0.205      0.838      -0.330       0.268
# ===================================================================================
# """

# %%
firstmile_train.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:        firstmile_train   No. Observations:                   74
# Model:                        MNLogit   Df Residuals:                       68
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                  0.1526
# Time:                        15:10:04   Log-Likelihood:                -66.714
# converged:                       True   LL-Null:                       -78.725
# Covariance Type:            nonrobust   LLR p-value:                 7.905e-05
# =====================================================================================
# firstmile_train=3       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# undergra              1.8971      0.619      3.064      0.002       0.684       3.111
# staff                 1.6094      1.095      1.469      0.142      -0.538       3.756
# gra                  -1.3863      0.645     -2.148      0.032      -2.651      -0.121
# -------------------------------------------------------------------------------------
# firstmile_train=4       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# undergra              1.2040      0.658      1.829      0.067      -0.086       2.494
# staff               -18.4045   9919.509     -0.002      0.999   -1.95e+04    1.94e+04
# gra                  -1.0986      0.577     -1.903      0.057      -2.230       0.033
# =====================================================================================
# """

# %%
lastmile_bus.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:           lastmile_bus   No. Observations:                  898
# Model:                        MNLogit   Df Residuals:                      886
# Method:                           MLE   Df Model:                           10
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                 0.07813
# Time:                        15:10:11   Log-Likelihood:                -308.09
# converged:                       True   LL-Null:                       -334.20
# Covariance Type:            nonrobust   LLR p-value:                 1.038e-07
# ====================================================================================
#   lastmile_bus=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# op_smartphone       -0.0353      0.257     -0.138      0.891      -0.539       0.468
# op_like_driving      0.1607      0.223      0.720      0.471      -0.277       0.598
# op_like_biking      -0.8711      0.244     -3.563      0.000      -1.350      -0.392
# op_like_transit     -0.0008      0.245     -0.003      0.997      -0.481       0.479
# op_limit_driving     0.1378      0.246      0.559      0.576      -0.345       0.621
# op_travel_wasted     0.1422      0.225      0.631      0.528      -0.300       0.584
# ------------------------------------------------------------------------------------
#   lastmile_bus=4       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# op_smartphone        0.2740      0.111      2.475      0.013       0.057       0.491
# op_like_driving      0.3458      0.093      3.728      0.000       0.164       0.528
# op_like_biking      -0.7213      0.119     -6.073      0.000      -0.954      -0.489
# op_like_transit      0.3707      0.102      3.626      0.000       0.170       0.571
# op_limit_driving     0.2651      0.102      2.600      0.009       0.065       0.465
# op_travel_wasted     0.1982      0.096      2.068      0.039       0.010       0.386
# ====================================================================================
# """

# %%
lastmile_train.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:         lastmile_train   No. Observations:                   74
# Model:                        MNLogit   Df Residuals:                       62
# Method:                           MLE   Df Model:                            9
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                  0.2770
# Time:                        15:10:13   Log-Likelihood:                -63.011
# converged:                       True   LL-Null:                       -87.153
# Covariance Type:            nonrobust   LLR p-value:                 2.261e-07
# ====================================================================================
# lastmile_train=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# op_like_transit     -0.5700      0.439     -1.300      0.194      -1.430       0.290
# undergra             2.5068      0.981      2.556      0.011       0.585       4.429
# op_like_biking      -0.4438      0.367     -1.210      0.226      -1.163       0.275
# op_need_car          0.4064      0.346      1.176      0.240      -0.271       1.084
# ------------------------------------------------------------------------------------
# lastmile_train=3       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# op_like_transit     -1.6589      0.687     -2.415      0.016      -3.005      -0.313
# undergra             4.5204      2.460      1.838      0.066      -0.301       9.341
# op_like_biking      -1.8165      0.695     -2.612      0.009      -3.180      -0.453
# op_need_car          1.8898      0.749      2.523      0.012       0.422       3.358
# ------------------------------------------------------------------------------------
# lastmile_train=4       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# op_like_transit      0.1807      0.288      0.628      0.530      -0.383       0.744
# undergra             1.0707      0.625      1.713      0.087      -0.154       2.296
# op_like_biking      -0.6822      0.260     -2.626      0.009      -1.192      -0.173
# op_need_car          0.5211      0.234      2.232      0.026       0.063       0.979
# ====================================================================================
# """
